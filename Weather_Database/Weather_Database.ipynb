# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?lat==units=Imperial&APPID=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_description = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          # Using round feature to match module table
                          "Lat": round(city_lat,2),
                          "Lng": round(city_lng,2),
                          # Table displayed in kelvins and after conversion needed to be rounded to match module table.
                          "Max Temp": round((city_max_temp-273.15)*1.8+32,2),
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | ishigaki
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | namibe
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | victoria point
# Processing Record 19 of Set 1 | geraldton
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | anastacio
# Processing Record 22 of Set 1 | muyezerskiy
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | antibes
# Processing Record 25 of Set 1 | kendari
# Processing Record 26 of Set 1 | wenchi
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | biga
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | zima
# Processing Record 31 of Set 1 | paita
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | las vegas
# Processing Record 34 of Set 1 | makakilo city
# Processing Record 35 of Set 1 | turan
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | husavik
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | san cristobal
# Processing Record 42 of Set 1 | tomatlan
# Processing Record 43 of Set 1 | portobelo
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | srednekolymsk
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | bucelas
# Processing Record 50 of Set 1 | raga
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | kieta
# Processing Record 4 of Set 2 | eldorado
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | kirchhain
# Processing Record 7 of Set 2 | idaho falls
# Processing Record 8 of Set 2 | genhe
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | urulga
# City not found. Skipping...
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | chapleau
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | belyy yar
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | setermoen
# Processing Record 18 of Set 2 | sambava
# Processing Record 19 of Set 2 | saint anthony
# Processing Record 20 of Set 2 | cap-aux-meules
# Processing Record 21 of Set 2 | hermiston
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | half moon bay
# Processing Record 24 of Set 2 | vanimo
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | hamilton
# Processing Record 30 of Set 2 | sayyan
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | patos
# Processing Record 34 of Set 2 | sorland
# Processing Record 35 of Set 2 | uthal
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | mae hong son
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | sidi ali
# Processing Record 45 of Set 2 | gojra
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | zhanaozen
# Processing Record 49 of Set 2 | landeck
# Processing Record 50 of Set 2 | mahebourg
# Processing Record 1 of Set 3 | verkhnyaya inta
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | westport
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | saint-leu
# Processing Record 9 of Set 3 | dengfeng
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | vostok
# Processing Record 15 of Set 3 | kutum
# Processing Record 16 of Set 3 | juneau
# Processing Record 17 of Set 3 | salvador
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | sisimiut
# Processing Record 20 of Set 3 | ust-maya
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | kollam
# Processing Record 23 of Set 3 | zonguldak
# Processing Record 24 of Set 3 | sola
# Processing Record 25 of Set 3 | talaya
# Processing Record 26 of Set 3 | nouadhibou
# Processing Record 27 of Set 3 | huron
# Processing Record 28 of Set 3 | pangody
# Processing Record 29 of Set 3 | megion
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | raul soares
# Processing Record 32 of Set 3 | ilheus
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | ossora
# Processing Record 35 of Set 3 | naze
# Processing Record 36 of Set 3 | presidencia roque saenz pena
# Processing Record 37 of Set 3 | hami
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | high level
# Processing Record 41 of Set 3 | jardim
# Processing Record 42 of Set 3 | beringovskiy
# Processing Record 43 of Set 3 | nakonde
# Processing Record 44 of Set 3 | rumuruti
# Processing Record 45 of Set 3 | katunayaka
# Processing Record 46 of Set 3 | puerto leguizamo
# Processing Record 47 of Set 3 | asyut
# Processing Record 48 of Set 3 | kalmunai
# Processing Record 49 of Set 3 | abnub
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | mahanje
# Processing Record 2 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | semme
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | itarema
# Processing Record 7 of Set 4 | cumana
# Processing Record 8 of Set 4 | aklavik
# Processing Record 9 of Set 4 | mecca
# Processing Record 10 of Set 4 | were ilu
# Processing Record 11 of Set 4 | pimentel
# Processing Record 12 of Set 4 | hambantota
# Processing Record 13 of Set 4 | himora
# City not found. Skipping...
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | rorvik
# Processing Record 17 of Set 4 | san quintin
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | moerai
# Processing Record 20 of Set 4 | richards bay
# Processing Record 21 of Set 4 | hudiksvall
# Processing Record 22 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 4 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | aden
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | banyo
# Processing Record 29 of Set 4 | kabul
# Processing Record 30 of Set 4 | norsup
# Processing Record 31 of Set 4 | bonnyville
# Processing Record 32 of Set 4 | avera
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | guatire
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | oranjemund
# Processing Record 38 of Set 4 | yumen
# Processing Record 39 of Set 4 | okmulgee
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | joshimath
# Processing Record 42 of Set 4 | isla mujeres
# Processing Record 43 of Set 4 | toropets
# Processing Record 44 of Set 4 | general pico
# Processing Record 45 of Set 4 | bredasdorp
# Processing Record 46 of Set 4 | okha
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | pucallpa
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | meulaboh
# Processing Record 1 of Set 5 | leningradskiy
# Processing Record 2 of Set 5 | waipawa
# Processing Record 3 of Set 5 | taoudenni
# Processing Record 4 of Set 5 | muzhi
# Processing Record 5 of Set 5 | mocorito
# Processing Record 6 of Set 5 | awjilah
# Processing Record 7 of Set 5 | tahta
# Processing Record 8 of Set 5 | mount pleasant
# Processing Record 9 of Set 5 | chitrakonda
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | shelby
# Processing Record 12 of Set 5 | moranbah
# Processing Record 13 of Set 5 | wuwei
# Processing Record 14 of Set 5 | mehamn
# Processing Record 15 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 5 | ampanihy
# Processing Record 17 of Set 5 | hasaki
# Processing Record 18 of Set 5 | lokoja
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | waitati
# Processing Record 21 of Set 5 | ketchikan
# Processing Record 22 of Set 5 | naryan-mar
# Processing Record 23 of Set 5 | dhidhdhoo
# Processing Record 24 of Set 5 | okhotsk
# Processing Record 25 of Set 5 | giraltovce
# Processing Record 26 of Set 5 | rocha
# Processing Record 27 of Set 5 | inuvik
# Processing Record 28 of Set 5 | petlad
# Processing Record 29 of Set 5 | gat
# Processing Record 30 of Set 5 | cacu
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | aksu
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | tiksi
# Processing Record 35 of Set 5 | sudbury
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | kuncice pod ondrejnikem
# Processing Record 38 of Set 5 | kjollefjord
# Processing Record 39 of Set 5 | carsamba
# Processing Record 40 of Set 5 | seymchan
# Processing Record 41 of Set 5 | vestmannaeyjar
# Processing Record 42 of Set 5 | jalu
# Processing Record 43 of Set 5 | uaua
# Processing Record 44 of Set 5 | bilma
# Processing Record 45 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 5 | griffith
# Processing Record 47 of Set 5 | la ronge
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | goderich
# Processing Record 50 of Set 5 | omboue
# Processing Record 1 of Set 6 | nakhon phanom
# Processing Record 2 of Set 6 | port-gentil
# Processing Record 3 of Set 6 | darhan
# Processing Record 4 of Set 6 | amahai
# Processing Record 5 of Set 6 | kedougou
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | tupik
# Processing Record 9 of Set 6 | lisakovsk
# Processing Record 10 of Set 6 | akyab
# Processing Record 11 of Set 6 | santa fe
# Processing Record 12 of Set 6 | yenagoa
# Processing Record 13 of Set 6 | yarim
# Processing Record 14 of Set 6 | marfino
# Processing Record 15 of Set 6 | hajnowka
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | almeirim
# Processing Record 18 of Set 6 | teofilo otoni
# Processing Record 19 of Set 6 | lorengau
# Processing Record 20 of Set 6 | mangrol
# Processing Record 21 of Set 6 | srivardhan
# Processing Record 22 of Set 6 | tupaciguara
# Processing Record 23 of Set 6 | myitkyina
# Processing Record 24 of Set 6 | togul
# Processing Record 25 of Set 6 | punta cardon
# Processing Record 26 of Set 6 | san jose
# Processing Record 27 of Set 6 | nancha
# Processing Record 28 of Set 6 | tiarei
# Processing Record 29 of Set 6 | andenes
# Processing Record 30 of Set 6 | bilibino
# Processing Record 31 of Set 6 | te anau
# Processing Record 32 of Set 6 | roma
# Processing Record 33 of Set 6 | kristiansund
# Processing Record 34 of Set 6 | pathein
# Processing Record 35 of Set 6 | severomorsk
# Processing Record 36 of Set 6 | mount isa
# Processing Record 37 of Set 6 | timra
# Processing Record 38 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | tarifa
# Processing Record 41 of Set 6 | lebu
# Processing Record 42 of Set 6 | kirakira
# Processing Record 43 of Set 6 | garowe
# Processing Record 44 of Set 6 | le port
# Processing Record 45 of Set 6 | scarborough
# Processing Record 46 of Set 6 | bambanglipuro
# Processing Record 47 of Set 6 | hegang
# Processing Record 48 of Set 6 | bonthe
# Processing Record 49 of Set 6 | bud
# Processing Record 50 of Set 6 | pudozh
# Processing Record 1 of Set 7 | matranovak
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | octeville
# Processing Record 4 of Set 7 | ouesso
# Processing Record 5 of Set 7 | nguruka
# Processing Record 6 of Set 7 | teya
# Processing Record 7 of Set 7 | henties bay
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | catamarca
# Processing Record 10 of Set 7 | hokitika
# Processing Record 11 of Set 7 | tiznit
# Processing Record 12 of Set 7 | jumla
# Processing Record 13 of Set 7 | inirida
# Processing Record 14 of Set 7 | santiago del estero
# Processing Record 15 of Set 7 | mendoza
# Processing Record 16 of Set 7 | praia
# Processing Record 17 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | porbandar
# Processing Record 19 of Set 7 | luwuk
# Processing Record 20 of Set 7 | dhone
# Processing Record 21 of Set 7 | birao
# Processing Record 22 of Set 7 | sehithwa
# Processing Record 23 of Set 7 | dharmabad
# Processing Record 24 of Set 7 | vila
# Processing Record 25 of Set 7 | high prairie
# Processing Record 26 of Set 7 | belen
# Processing Record 27 of Set 7 | dalby
# Processing Record 28 of Set 7 | lanja
# Processing Record 29 of Set 7 | buala
# Processing Record 30 of Set 7 | urucui
# Processing Record 31 of Set 7 | asau
# Processing Record 32 of Set 7 | manavalakurichi
# Processing Record 33 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | grenville
# Processing Record 35 of Set 7 | los llanos de aridane
# Processing Record 36 of Set 7 | dedougou
# Processing Record 37 of Set 7 | lagoa
# Processing Record 38 of Set 7 | kovur
# Processing Record 39 of Set 7 | lebowakgomo
# Processing Record 40 of Set 7 | luanda
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | ormara
# Processing Record 43 of Set 7 | la paz
# Processing Record 44 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 7 | la reforma
# Processing Record 46 of Set 7 | kuzedeyevo
# Processing Record 47 of Set 7 | olafsvik
# Processing Record 48 of Set 7 | fairbanks
# Processing Record 49 of Set 7 | mildura
# Processing Record 50 of Set 7 | manhattan
# Processing Record 1 of Set 8 | reconquista
# Processing Record 2 of Set 8 | cabo san lucas
# Processing Record 3 of Set 8 | sumbawanga
# Processing Record 4 of Set 8 | rio gallegos
# Processing Record 5 of Set 8 | vao
# Processing Record 6 of Set 8 | santa maria
# Processing Record 7 of Set 8 | baijiantan
# Processing Record 8 of Set 8 | mount gambier
# Processing Record 9 of Set 8 | waddan
# Processing Record 10 of Set 8 | tomigusuku
# Processing Record 11 of Set 8 | gornopravdinsk
# Processing Record 12 of Set 8 | baykit
# Processing Record 13 of Set 8 | sanhsia
# City not found. Skipping...
# Processing Record 14 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 8 | deputatskiy
# Processing Record 16 of Set 8 | namatanai
# Processing Record 17 of Set 8 | narsaq
# Processing Record 18 of Set 8 | esik
# Processing Record 19 of Set 8 | rawatsar
# Processing Record 20 of Set 8 | eureka
# Processing Record 21 of Set 8 | toamasina
# Processing Record 22 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 23 of Set 8 | udachnyy
# Processing Record 24 of Set 8 | the valley
# Processing Record 25 of Set 8 | korla
# Processing Record 26 of Set 8 | new norfolk
# Processing Record 27 of Set 8 | christchurch
# Processing Record 28 of Set 8 | flinders
# Processing Record 29 of Set 8 | ola
# Processing Record 30 of Set 8 | brahmapuri
# City not found. Skipping...
# Processing Record 31 of Set 8 | pangnirtung
# Processing Record 32 of Set 8 | yulara
# Processing Record 33 of Set 8 | colac
# Processing Record 34 of Set 8 | najran
# Processing Record 35 of Set 8 | williams lake
# Processing Record 36 of Set 8 | karratha
# Processing Record 37 of Set 8 | ngunguru
# Processing Record 38 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 8 | clyde river
# Processing Record 40 of Set 8 | barrhead
# Processing Record 41 of Set 8 | kuito
# Processing Record 42 of Set 8 | ballina
# Processing Record 43 of Set 8 | puerto escondido
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | isangel
# Processing Record 46 of Set 8 | chachapoyas
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | kovdor
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | college
# Processing Record 1 of Set 9 | severnyy
# Processing Record 2 of Set 9 | huilong
# Processing Record 3 of Set 9 | yusva
# City not found. Skipping...
# Processing Record 4 of Set 9 | urengoy
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | poum
# Processing Record 7 of Set 9 | havoysund
# Processing Record 8 of Set 9 | ust-nera
# Processing Record 9 of Set 9 | litovko
# Processing Record 10 of Set 9 | ninohe
# Processing Record 11 of Set 9 | margate
# Processing Record 12 of Set 9 | kotelnich
# Processing Record 13 of Set 9 | bethel
# Processing Record 14 of Set 9 | vysokaya gora
# Processing Record 15 of Set 9 | zyryanka
# Processing Record 16 of Set 9 | saint-pierre
# Processing Record 17 of Set 9 | birjand
# Processing Record 18 of Set 9 | ternate
# Processing Record 19 of Set 9 | bulaevo
# Processing Record 20 of Set 9 | sept-iles
# Processing Record 21 of Set 9 | san vicente
# Processing Record 22 of Set 9 | bathsheba
# Processing Record 23 of Set 9 | road town
# Processing Record 24 of Set 9 | vardo
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | katsuura
# Processing Record 27 of Set 9 | port hardy
# Processing Record 28 of Set 9 | ekibastuz
# Processing Record 29 of Set 9 | warrnambool
# Processing Record 30 of Set 9 | manaus
# Processing Record 31 of Set 9 | incourt
# Processing Record 32 of Set 9 | karatau
# Processing Record 33 of Set 9 | luau
# Processing Record 34 of Set 9 | kaduna
# Processing Record 35 of Set 9 | verkhnevilyuysk
# Processing Record 36 of Set 9 | nipawin
# Processing Record 37 of Set 9 | ijui
# Processing Record 38 of Set 9 | camocim
# Processing Record 39 of Set 9 | ponta do sol
# Processing Record 40 of Set 9 | cap-chat
# Processing Record 41 of Set 9 | chicama
# Processing Record 42 of Set 9 | atbasar
# Processing Record 43 of Set 9 | martapura
# Processing Record 44 of Set 9 | grootfontein
# Processing Record 45 of Set 9 | gorom-gorom
# Processing Record 46 of Set 9 | oranjestad
# Processing Record 47 of Set 9 | ewa beach
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | bubaque
# Processing Record 50 of Set 9 | coihaique
# Processing Record 1 of Set 10 | prilep
# Processing Record 2 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 10 | sinnamary
# Processing Record 4 of Set 10 | banjarmasin
# Processing Record 5 of Set 10 | butajira
# Processing Record 6 of Set 10 | sorsk
# Processing Record 7 of Set 10 | rio grande
# Processing Record 8 of Set 10 | gayny
# Processing Record 9 of Set 10 | oussouye
# Processing Record 10 of Set 10 | san andres
# Processing Record 11 of Set 10 | ancud
# Processing Record 12 of Set 10 | verkhniy fiagdon
# Processing Record 13 of Set 10 | puri
# Processing Record 14 of Set 10 | haines junction
# Processing Record 15 of Set 10 | kidal
# Processing Record 16 of Set 10 | khandbari
# Processing Record 17 of Set 10 | dire
# Processing Record 18 of Set 10 | alanya
# Processing Record 19 of Set 10 | taltal
# Processing Record 20 of Set 10 | ongole
# Processing Record 21 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 10 | cap malheureux
# Processing Record 23 of Set 10 | hargeysa
# Processing Record 24 of Set 10 | takoradi
# Processing Record 25 of Set 10 | elat
# Processing Record 26 of Set 10 | labytnangi
# Processing Record 27 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 10 | mitsamiouli
# Processing Record 29 of Set 10 | evinayong
# Processing Record 30 of Set 10 | healdsburg
# Processing Record 31 of Set 10 | simpang
# Processing Record 32 of Set 10 | nome
# Processing Record 33 of Set 10 | ust-koksa
# Processing Record 34 of Set 10 | svetlogorsk
# Processing Record 35 of Set 10 | pabna
# Processing Record 36 of Set 10 | salekhard
# Processing Record 37 of Set 10 | krasnyy luch
# Processing Record 38 of Set 10 | tucuman
# Processing Record 39 of Set 10 | juba
# Processing Record 40 of Set 10 | new castle
# Processing Record 41 of Set 10 | belmonte
# Processing Record 42 of Set 10 | hobyo
# Processing Record 43 of Set 10 | poya
# Processing Record 44 of Set 10 | fortuna
# Processing Record 45 of Set 10 | broome
# Processing Record 46 of Set 10 | kjopsvik
# Processing Record 47 of Set 10 | tazovskiy
# Processing Record 48 of Set 10 | amiens
# Processing Record 49 of Set 10 | taybad
# Processing Record 50 of Set 10 | todos santos
# Processing Record 1 of Set 11 | arlit
# Processing Record 2 of Set 11 | zhaotong
# Processing Record 3 of Set 11 | plouzane
# Processing Record 4 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 11 | egvekinot
# Processing Record 6 of Set 11 | mandalgovi
# Processing Record 7 of Set 11 | port moresby
# Processing Record 8 of Set 11 | tezu
# Processing Record 9 of Set 11 | nacogdoches
# Processing Record 10 of Set 11 | maceio
# Processing Record 11 of Set 11 | guozhen
# Processing Record 12 of Set 11 | abeche
# Processing Record 13 of Set 11 | sarapulka
# Processing Record 14 of Set 11 | mogadishu
# Processing Record 15 of Set 11 | coquimbo
# Processing Record 16 of Set 11 | montelibano
# Processing Record 17 of Set 11 | kayattar
# Processing Record 18 of Set 11 | kakching
# Processing Record 19 of Set 11 | minador do negrao
# Processing Record 20 of Set 11 | duma
# Processing Record 21 of Set 11 | anadyr
# Processing Record 22 of Set 11 | kahului
# Processing Record 23 of Set 11 | villazon
# Processing Record 24 of Set 11 | lososina
# Processing Record 25 of Set 11 | aleksandrov gay
# Processing Record 26 of Set 11 | zhangye
# Processing Record 27 of Set 11 | marzuq
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | golden
# Processing Record 30 of Set 11 | kailua
# Processing Record 31 of Set 11 | faya
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | soe
# Processing Record 34 of Set 11 | shahreza
# Processing Record 35 of Set 11 | coolum beach
# Processing Record 36 of Set 11 | labuhan
# Processing Record 37 of Set 11 | ostrovnoy
# Processing Record 38 of Set 11 | marathon
# Processing Record 39 of Set 11 | tremedal
# Processing Record 40 of Set 11 | simoes
# Processing Record 41 of Set 11 | goundam
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 11 | topsham
# Processing Record 45 of Set 11 | ayan
# Processing Record 46 of Set 11 | jeremie
# Processing Record 47 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 11 | merauke
# Processing Record 49 of Set 11 | maun
# Processing Record 50 of Set 11 | nang rong
# Processing Record 1 of Set 12 | brae
# Processing Record 2 of Set 12 | balsas
# Processing Record 3 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 12 | gazanjyk
# Processing Record 5 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 12 | middletown
# Processing Record 7 of Set 12 | adrar
# Processing Record 8 of Set 12 | koumra
# Processing Record 9 of Set 12 | singleton
# Processing Record 10 of Set 12 | lasa
# Processing Record 11 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 12 | penzance
# Processing Record 13 of Set 12 | collie
# Processing Record 14 of Set 12 | suao
# City not found. Skipping...
# Processing Record 15 of Set 12 | tucupita
# Processing Record 16 of Set 12 | nendaz
# Processing Record 17 of Set 12 | mabaruma
# Processing Record 18 of Set 12 | onega
# Processing Record 19 of Set 12 | progreso
# Processing Record 20 of Set 12 | karasjok
# Processing Record 21 of Set 12 | romanovo
# Processing Record 22 of Set 12 | fukue
# Processing Record 23 of Set 12 | tautira
# Processing Record 24 of Set 12 | acuexcomac
# Processing Record 25 of Set 12 | iraray
# Processing Record 26 of Set 12 | rawah
# Processing Record 27 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 12 | daru
# Processing Record 29 of Set 12 | arawa
# Processing Record 30 of Set 12 | roebourne
# Processing Record 31 of Set 12 | dakar
# Processing Record 32 of Set 12 | kiunga
# Processing Record 33 of Set 12 | kyshtovka
# Processing Record 34 of Set 12 | verkhnyaya salda
# Processing Record 35 of Set 12 | bereda
# Processing Record 36 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 12 | olavarria
# Processing Record 38 of Set 12 | rawson
# Processing Record 39 of Set 12 | voh
# Processing Record 40 of Set 12 | findlay
# Processing Record 41 of Set 12 | macau
# Processing Record 42 of Set 12 | san luis
# Processing Record 43 of Set 12 | shurugwi
# Processing Record 44 of Set 12 | along
# Processing Record 45 of Set 12 | fort-shevchenko
# Processing Record 46 of Set 12 | otane
# Processing Record 47 of Set 12 | camacupa
# Processing Record 48 of Set 12 | isabela
# Processing Record 49 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 13 | hanmer springs
# Processing Record 4 of Set 13 | evensk
# Processing Record 5 of Set 13 | alta floresta
# Processing Record 6 of Set 13 | leua
# Processing Record 7 of Set 13 | buzmeyin
# Processing Record 8 of Set 13 | matara
# Processing Record 9 of Set 13 | liwale
# Processing Record 10 of Set 13 | sayansk
# Processing Record 11 of Set 13 | canutama
# Processing Record 12 of Set 13 | talas
# Processing Record 13 of Set 13 | san juan
# Processing Record 14 of Set 13 | burica
# City not found. Skipping...
# Processing Record 15 of Set 13 | sistranda
# Processing Record 16 of Set 13 | sena madureira
# Processing Record 17 of Set 13 | tual
# Processing Record 18 of Set 13 | pacifica
# Processing Record 19 of Set 13 | lata
# Processing Record 20 of Set 13 | faanui
# Processing Record 21 of Set 13 | gloversville
# Processing Record 22 of Set 13 | sindor
# Processing Record 23 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 13 | port lincoln
# Processing Record 25 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 13 | mirnyy
# Processing Record 27 of Set 13 | hofn
# Processing Record 28 of Set 13 | gorontalo
# Processing Record 29 of Set 13 | lamar
# Processing Record 30 of Set 13 | vila velha
# Processing Record 31 of Set 13 | constitucion
# Processing Record 32 of Set 13 | sabha
# Processing Record 33 of Set 13 | meiganga
# Processing Record 34 of Set 13 | banchory
# Processing Record 35 of Set 13 | homer
# Processing Record 36 of Set 13 | ayagoz
# Processing Record 37 of Set 13 | behat
# Processing Record 38 of Set 13 | bend
# Processing Record 39 of Set 13 | port hedland
# Processing Record 40 of Set 13 | akdepe
# Processing Record 41 of Set 13 | huambo
# Processing Record 42 of Set 13 | monywa
# Processing Record 43 of Set 13 | rundu
# Processing Record 44 of Set 13 | maragogi
# Processing Record 45 of Set 13 | kloulklubed
# Processing Record 46 of Set 13 | vila franca do campo
# Processing Record 47 of Set 13 | lichinga
# Processing Record 48 of Set 13 | koslan
# Processing Record 49 of Set 13 | vawkavysk
# Processing Record 50 of Set 13 | los arabos
# Processing Record 1 of Set 14 | holstebro
# Processing Record 2 of Set 14 | guilin
# Processing Record 3 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 5 of Set 14 | deder
# Processing Record 6 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 14 | papagaios
# Processing Record 8 of Set 14 | kielce
# Processing Record 9 of Set 14 | vynohradivka
# Processing Record 10 of Set 14 | taian
# Processing Record 11 of Set 14 | kuching
# Processing Record 12 of Set 14 | necochea
# Processing Record 13 of Set 14 | mega
# Processing Record 14 of Set 14 | zhigansk
# Processing Record 15 of Set 14 | kaspiyskiy
# Processing Record 16 of Set 14 | kudahuvadhoo
# Processing Record 17 of Set 14 | ulaangom
# Processing Record 18 of Set 14 | jibuti
# Processing Record 19 of Set 14 | srandakan
# Processing Record 20 of Set 14 | kinshasa
# Processing Record 21 of Set 14 | salinopolis
# Processing Record 22 of Set 14 | thessalon
# Processing Record 23 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 14 | lienz
# Processing Record 25 of Set 14 | santa rosalia
# Processing Record 26 of Set 14 | khonsa
# Processing Record 27 of Set 14 | vilhena
# Processing Record 28 of Set 14 | sosnovo-ozerskoye
# Processing Record 29 of Set 14 | shu
# Processing Record 30 of Set 14 | marawi
# Processing Record 31 of Set 14 | robinson
# Processing Record 32 of Set 14 | olinda
# Processing Record 33 of Set 14 | chake chake
# Processing Record 34 of Set 14 | sangar
# Processing Record 35 of Set 14 | chodavaram
# Processing Record 36 of Set 14 | kathmandu
# Processing Record 37 of Set 14 | oytal
# Processing Record 38 of Set 14 | fengkou
# Processing Record 39 of Set 14 | kundiawa
# Processing Record 40 of Set 14 | santa cruz
# Processing Record 41 of Set 14 | buchanan
# Processing Record 42 of Set 14 | jega
# Processing Record 43 of Set 14 | cartagena
# Processing Record 44 of Set 14 | muli
# Processing Record 45 of Set 14 | wewak
# Processing Record 46 of Set 14 | cururupu
# Processing Record 47 of Set 14 | mumford
# Processing Record 48 of Set 14 | ahipara
# Processing Record 49 of Set 14 | coro
# Processing Record 50 of Set 14 | fredonia
# Processing Record 1 of Set 15 | talnakh
# Processing Record 2 of Set 15 | ponta delgada
# Processing Record 3 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 15 | magistralnyy
# Processing Record 5 of Set 15 | ageyevo
# Processing Record 6 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 15 | fartura
# Processing Record 8 of Set 15 | klaksvik
# Processing Record 9 of Set 15 | beira
# Processing Record 10 of Set 15 | samfya
# Processing Record 11 of Set 15 | maldonado
# Processing Record 12 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 15 | yithion
# City not found. Skipping...
# Processing Record 14 of Set 15 | sakakah
# Processing Record 15 of Set 15 | port macquarie
# Processing Record 16 of Set 15 | mayumba
# Processing Record 17 of Set 15 | maniitsoq
# Processing Record 18 of Set 15 | trinidad
# Processing Record 19 of Set 15 | duekoue
# Processing Record 20 of Set 15 | ivolginsk
# Processing Record 21 of Set 15 | emirdag
# Processing Record 22 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 23 of Set 15 | ulladulla
# Processing Record 24 of Set 15 | eyl
# Processing Record 25 of Set 15 | berlevag
# Processing Record 26 of Set 15 | raton
# Processing Record 27 of Set 15 | cobourg
# Processing Record 28 of Set 15 | tabou
# Processing Record 29 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 15 | lethem
# Processing Record 31 of Set 15 | dudinka
# Processing Record 32 of Set 15 | qasigiannguit
# Processing Record 33 of Set 15 | arco
# Processing Record 34 of Set 15 | angra
# City not found. Skipping...
# Processing Record 35 of Set 15 | abha
# Processing Record 36 of Set 15 | batticaloa
# Processing Record 37 of Set 15 | jiexiu
# Processing Record 38 of Set 15 | cairns
# Processing Record 39 of Set 15 | varzea da palma
# Processing Record 40 of Set 15 | porto novo
# Processing Record 41 of Set 15 | singaparna
# Processing Record 42 of Set 15 | glossop
# Processing Record 43 of Set 15 | safaga
# Processing Record 44 of Set 15 | sao joao da barra
# Processing Record 45 of Set 15 | kasempa
# Processing Record 46 of Set 15 | elizabeth city
# Processing Record 47 of Set 15 | entre rios
# Processing Record 48 of Set 15 | ayr
# Processing Record 49 of Set 15 | turbat
# Processing Record 50 of Set 15 | tsybli
# Processing Record 1 of Set 16 | moroni
# Processing Record 2 of Set 16 | alyangula
# Processing Record 3 of Set 16 | tobol
# Processing Record 4 of Set 16 | puerto carreno
# Processing Record 5 of Set 16 | saint-joseph
# Processing Record 6 of Set 16 | tabuk
# Processing Record 7 of Set 16 | marrakesh
# Processing Record 8 of Set 16 | singaraja
# Processing Record 9 of Set 16 | manbij
# Processing Record 10 of Set 16 | tome-acu
# City not found. Skipping...
# Processing Record 11 of Set 16 | bara
# Processing Record 12 of Set 16 | jangaon
# Processing Record 13 of Set 16 | ferkessedougou
# Processing Record 14 of Set 16 | sharjah
# Processing Record 15 of Set 16 | ingham
# Processing Record 16 of Set 16 | acapulco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Albany  42.60  -73.97     57.33        98          99        2.36
# 1         Rikitea -23.12 -134.97     69.24        58          51        9.59
# 2          Dingle  11.00  122.67     77.14        90          93        2.90
# 3           Bluff -46.60  168.33     34.81        66          86       10.89
# 4      Butaritari   3.07  172.79     81.70        70          29        8.87
# 5  Ribeira Grande  38.52  -28.70     68.40        88          75        3.09
# 6           Sitka  57.05 -135.33     55.54        89         100        3.52
# 7        Ishigaki  24.34  124.16     81.81        76           3        6.89
# 8     Port Alfred -33.59   26.89     65.68        85         100        6.33
# 9          Namibe -15.20   12.15     66.65        81          23        5.33
#
#   Country          Current Description
# 0      US              overcast clouds
# 1      PF                broken clouds
# 2      PH              overcast clouds
# 3      NZ                   light snow
# 4      KI             scattered clouds
# 5      PT  light intensity shower rain
# 6      US              overcast clouds
# 7      JP                    clear sky
# 8      ZA              overcast clouds
# 9      AO                   few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany      US  42.60  -73.97     57.33        98          99
# 1         Rikitea      PF -23.12 -134.97     69.24        58          51
# 2          Dingle      PH  11.00  122.67     77.14        90          93
# 3           Bluff      NZ -46.60  168.33     34.81        66          86
# 4      Butaritari      KI   3.07  172.79     81.70        70          29
# 5  Ribeira Grande      PT  38.52  -28.70     68.40        88          75
# 6           Sitka      US  57.05 -135.33     55.54        89         100
# 7        Ishigaki      JP  24.34  124.16     81.81        76           3
# 8     Port Alfred      ZA -33.59   26.89     65.68        85         100
# 9          Namibe      AO -15.20   12.15     66.65        81          23
#
#    Wind Speed          Current Description
# 0        2.36              overcast clouds
# 1        9.59                broken clouds
# 2        2.90              overcast clouds
# 3       10.89                   light snow
# 4        8.87             scattered clouds
# 5        3.09  light intensity shower rain
# 6        3.52              overcast clouds
# 7        6.89                    clear sky
# 8        6.33              overcast clouds
# 9        5.33                   few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file - label index row
city_data_df.to_csv(output_data_file, index_label="City_ID")
